# %% [markdown]
# # Webscraping and Social Media Scraping Project
# ## 08.04.2025
#
# ### Anna Kędzierska-Głodek (332945), Stanisław Godlewski (473016)

# %% [markdown]
# # 1. Choise of the website
#     https://www.arbeitnow.com/
#
#
# ## 1.1. Reason
# The data from the Arbeitnow portal was selected due to its public availability, transparency, and up-to-date job listings. The job postings include salary ranges, location, work mode (e.g., remote or on-site), and technical requirements — making them highly valuable for analyzing the job market. This dataset enables the assessment of differences in compensation, demand for specific technologies, and the popularity of remote work. It also allows for tracking occupational trends over time, which makes it a useful resource for job seekers.
#
#
# ## 1.2. https://www.arbeitnow.com/robots.txt
#
#
#            User-agent: *              # any user-agent
#            Disallow:                  # all parts of the website are allowed to be accessed by web crawlers.
#            Disallow: /*?__hstc
#
#
#
#
#
# ## 1.3. https://www.arbeitnow.com/terms
#
#       Use License
#             a. Permission is granted to temporarily download one copy of the materials (information or software) on arbeitnow's website for personal, non-commercial transitory viewing only. This is the grant of a license, not a transfer of title, and under this license you may not:
#                 i. modify or copy the materials;
#                 ii. use the materials for any commercial purpose, or for any public display (commercial or non-commercial);
#                 iii. attempt to decompile or reverse engineer any software contained on arbeitnow's website;
#                 iv. remove any copyright or other proprietary notations from the materials; or
#                 v. ransfer the materials to another person or "mirror" the materials on any other server.
#             b. This license shall automatically terminate if you violate any of these restrictions and may be terminated by arbeitnow at any time. Upon terminating your viewing of these materials or upon the termination of this license, you must destroy any downloaded materials in your possession whether in electronic or printed format.

# %% [markdown]
# # 2. Collecting data from the website

# %% [markdown]
# ## 2.1. Instal packages, import libraries and tools

# %%
# Instal required packages
# %pip install pandas numpy selenium webdriver_manager

# Import system and data libraries
import time  # used to pause for JS loading and measure execution time
import re  # used for extracting text
import pandas as pd  # used to store and export scraped data
import numpy as np  # used for random time delays
import csv # used to write CSV files
import os # used to create directories

# Import web scraping tools
from bs4 import BeautifulSoup  # used to parse HTML
from selenium import webdriver  # controls the web browser
from selenium.webdriver.common.by import By  # used to locate elements on page
from selenium.webdriver.chrome.service import Service  # manages ChromeDriver
from selenium.webdriver.support.ui import Select  # used to select dropdown options
from webdriver_manager.chrome import ChromeDriverManager  # installs the ChromeDriver
# Out:
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.12/site-packages (1.26.4)
# Requirement already satisfied: selenium in /opt/anaconda3/lib/python3.12/site-packages (4.31.0)
# Requirement already satisfied: webdriver_manager in /opt/anaconda3/lib/python3.12/site-packages (4.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (2023.3)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/anaconda3/lib/python3.12/site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.26.20)
# Requirement already satisfied: trio~=0.17 in /opt/anaconda3/lib/python3.12/site-packages (from selenium) (0.29.0)
# Requirement already satisfied: trio-websocket~=0.9 in /opt/anaconda3/lib/python3.12/site-packages (from selenium) (0.12.2)
# Requirement already satisfied: certifi>=2021.10.8 in /opt/anaconda3/lib/python3.12/site-packages (from selenium) (2025.1.31)
# Requirement already satisfied: typing_extensions~=4.9 in /opt/anaconda3/lib/python3.12/site-packages (from selenium) (4.11.0)
# Requirement already satisfied: websocket-client~=1.8 in /opt/anaconda3/lib/python3.12/site-packages (from selenium) (1.8.0)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.12/site-packages (from webdriver_manager) (2.32.3)
# Requirement already satisfied: python-dotenv in /opt/anaconda3/lib/python3.12/site-packages (from webdriver_manager) (0.21.0)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.12/site-packages (from webdriver_manager) (24.1)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: attrs>=23.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from trio~=0.17->selenium) (25.3.0)
# Requirement already satisfied: sortedcontainers in /opt/anaconda3/lib/python3.12/site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in /opt/anaconda3/lib/python3.12/site-packages (from trio~=0.17->selenium) (3.7)
# Requirement already satisfied: outcome in /opt/anaconda3/lib/python3.12/site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: wsproto>=0.14 in /opt/anaconda3/lib/python3.12/site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /opt/anaconda3/lib/python3.12/site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests->webdriver_manager) (3.3.2)
# Requirement already satisfied: h11<1,>=0.9.0 in /opt/anaconda3/lib/python3.12/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 2.2. Check total number of pages for English-speaking jobs

# %%
# Launch Chrome browser
service = Service(ChromeDriverManager().install())
options_chrome = webdriver.ChromeOptions() # set Chrome options
options_chrome.add_argument("--incognito")  # open browser in incognito mode
options_chrome.add_argument("--disable-notifications")  # block system push notifications
options_chrome.add_argument("--disable-infobars")  # hide infobars
options_chrome.add_argument("--disable-extensions")  # disable browser extensions
options_chrome.add_argument("--no-sandbox") # disable sandboxing
options_chrome.add_argument("--disable-dev-shm-usage") # overcome limited resource problems
options_chrome.add_argument("--headless")  # run browser without a visible UI

driver = webdriver.Chrome(service=service, options=options_chrome)  # launch Chrome with specified options

# Open website
url = "https://www.arbeitnow.com"
driver.get(url) # request the page with the specified URL

# Cilck button to search English-speaking jobs
button = driver.find_element(By.CSS_SELECTOR, 'button[aria-label="tag english speaking"]')
button.click()

# Wait to ensure the content is fully loaded
time.sleep(3) # wait for 3 seconds

# Read the total number of pages
try:
    last_page_element = driver.find_element(By.ID, "last_page")
    last_page = int(last_page_element.text.strip())  # strip whitespace and convert to integer
except:
    last_page = 1  # if not found, assume only 1 page
print(f"Total number of pages: {last_page}")

url_1 = driver.current_url
print("url:", url_1)

url_base = url_1.rsplit('=', 1)[0] + '=' # get the base URL by removing the last part after '='
url_base = url_base.replace("sort_by=relevance", "sort_by=newest")
print("url_base:", url_base)
# Out:
# Total number of pages: 31
# url: https://www.arbeitnow.com/?search=&tags=%5B%22english+speaking%22%5D&sort_by=relevance&page=1
# url_base: https://www.arbeitnow.com/?search=&tags=%5B%22english+speaking%22%5D&sort_by=newest&page=

# %% [markdown]
# ## 2.3. Collect links

# %%
# Start tracking execution time
start_time = time.time()

# Launch Chrome browser again for scraping job offers
driver = webdriver.Chrome(service=service, options=options_chrome)

# Create an empty list to store job offer URLs
job_links = []

# Loop through each search result page
for i in range(1, last_page+1):
#for i in range(1, 2): # limit for testing
    url = url_base + str(i)
    driver.get(url)  # open the page
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")  # scroll down to load content
    time.sleep(np.random.chisquare(1) + 2.5)  # wait for content to load

    # Find all job links on the page
    tags = driver.find_elements(By.CSS_SELECTOR, 'a[data-job-item-link="true"]')
    for tag in tags:
        href = tag.get_attribute('href')  # extract URL from link
        if href and href not in job_links:
            job_links.append(href)  # store only unique links

    print(f"Page {i} – found: {len(tags)} links, total collected: {len(job_links)}")

end_time = time.time()

pd.DataFrame({'Job_URL': job_links}).to_csv("arbeitnow_job_links.csv", index=False)

print(f"\nTotal number of job links collected: {len(job_links)}")
print(f"Time: {end_time - start_time:.2f} seconds")
# Out:
# Page 1 – found: 35 links, total collected: 35
# Page 2 – found: 35 links, total collected: 70
# Page 3 – found: 35 links, total collected: 105
# Page 4 – found: 35 links, total collected: 140
# Page 5 – found: 35 links, total collected: 175
# Page 6 – found: 35 links, total collected: 210
# Page 7 – found: 35 links, total collected: 245
# Page 8 – found: 35 links, total collected: 280
# Page 9 – found: 35 links, total collected: 315
# Page 10 – found: 35 links, total collected: 350
# Page 11 – found: 35 links, total collected: 385
# Page 12 – found: 35 links, total collected: 420
# Page 13 – found: 35 links, total collected: 455
# Page 14 – found: 35 links, total collected: 490
# Page 15 – found: 35 links, total collected: 525
# Page 16 – found: 35 links, total collected: 560
# Page 17 – found: 35 links, total collected: 595
# Page 18 – found: 35 links, total collected: 630
# Page 19 – found: 35 links, total collected: 665
# Page 20 – found: 35 links, total collected: 700
# Page 21 – found: 35 links, total collected: 735
# Page 22 – found: 35 links, total collected: 770
# Page 23 – found: 35 links, total collected: 805
# Page 24 – found: 35 links, total collected: 840
# Page 25 – found: 35 links, total collected: 875
# Page 26 – found: 35 links, total collected: 910
# Page 27 – found: 35 links, total collected: 945
# Page 28 – found: 35 links, total collected: 980
# Page 29 – found: 35 links, total collected: 1015
# Page 30 – found: 35 links, total collected: 1050
# Page 31 – found: 24 links, total collected: 1074
#
# Total number of job links collected: 1074
# Time: 113.36 seconds

# %% [markdown]
# ## 2.4. Define list of keywords, function to extract keywords from text, and set limit of how many job offers to scrape

# %%
# Define a list of keywords to extract from job descriptions
keywords_list = [
    "Python", "SQL", "R", "Pandas", "NumPy", "Matplotlib", "TensorFlow", "Keras", 
    "PyTorch", "Scikit-learn", "Hadoop", "Spark", "AWS", "GCP", "Azure", "Docker", 
    "Kubernetes", "PostgreSQL", "MongoDB", "Airflow", "Tableau", "Power BI", "Linux", 
    "Git", "GitHub", "Bitbucket", "Java", "Scala", "NoSQL", "Flask", "Django", "Machine Learning", "ML",
    "BigQuery", "ETL", "Data Warehouse", "Data Lake", "Data Pipeline", "Data Science",
    "Data Engineering", "Business Intelligence", "BI", "Data Visualization", "Deep Learning",
    "NLP", "Natural Language Processing", "Statistics", "Algorithms", "Data Mining", 
    "Statistical Analysis", "Agile", "Scrum", "Kanban", "DevOps", "CI/CD",
    "Microservices", "REST", "GraphQL", "API", "Web Scraping", "Web Crawling", 
    "Google Cloud", "Cloud", "SAP", "Apache", "Jira", "Confluence"
]

# Define function to extract keywords from text using regex
def extract_keywords(text, keywords_list):
    found = []  # create empty list to store matched keywords
    for tech in keywords_list:
        if tech == "R":
            # match "R" only if it's a separate word 
            if re.search(r'\bR\b', text):
                found.append(tech)
        else:
            # match other keywords case-insensitively
            if re.search(rf'\b{re.escape(tech)}\b', text, re.IGNORECASE):
                found.append(tech)
    return ", ".join(sorted(set(found)))  # return sorted, unique list

# %% [markdown]
# ## 2.5. Scrape job details

# %%
# Load job links from file 
links_df = pd.read_csv("arbeitnow_job_links.csv") 
job_links = links_df['Job_URL'].dropna().unique().tolist() # load job links from CSV file to list

#Define how many job offers to scrape
LIMIT_LINKS = len(job_links)  # all links
#LIMIT_LINKS = 50 # limit for testing
BATCH_SIZE = 50 # save at once
output_file = "arbeitnow_jobs.csv"

print(f"Loaded {len(job_links[:LIMIT_LINKS])} job links.")

# Remove old CSV file if exists
if os.path.exists(output_file):
    os.remove(output_file)

# Define headers
fieldnames = [
    "Date_Posted", "Title", "Company", "Location", "Remote",
    "Salary", "Keywords", "Description", "URL", "Apply_Link"
]

# Create CSV file with headers before scraping
with open(output_file, mode="w", newline="", encoding="utf-8") as f:
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    writer.writeheader()

# Launch Chrome browser for scraping job offers
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options_chrome)

# Track execution time
start_time = time.time()

batch = [] # list to store job data for batch processing
total_saved = 0 # total number of saved job offers

# Loop over job offers
for idx, url in enumerate(job_links[:LIMIT_LINKS]):
    print(f"Scraping job offer {idx + 1}/{LIMIT_LINKS} ({(idx + 1) / LIMIT_LINKS * 100:.2f}%): {url}")
    try:
        driver.get(url) # open job offer page

        # Parse page source with BeautifulSoup
        soup = BeautifulSoup(driver.page_source, "html.parser")

        # Extract description
        desc_tag = soup.select_one('div[itemprop="description"]') # extract description
        if not desc_tag:
            print(f"Skipping {url}: No description found.")
            continue

        description = desc_tag.get_text(separator="\n", strip=True) if desc_tag else ""
        
        # Extract keywords from description
        keywords = extract_keywords(description, keywords_list)
        if not keywords:
            print(f"----> skipping - no keywords found")
            continue  
        else:
            print(f"-> {keywords}")

        # Extract posting date
        time_tag = soup.find("time")
        date_posted = time_tag["datetime"] if time_tag and "datetime" in time_tag.attrs else ""

        # Extract title
        title_tag = soup.find("h1")
        title = title_tag.get_text(strip=True) if title_tag else ""

        # Extract company
        company_tag = soup.select_one('a[itemprop="hiringOrganization"]')
        company = company_tag.get_text(strip=True) if company_tag else ""

        # Extract location and check if job is remote
        location_tag = soup.select_one("p.flex.items-center span.text-gray-600")
        location = location_tag.get_text(strip=True) if location_tag else ""
        # Check for any remote button e.g. Remote, Remote full time
        remote = "Yes" if "Remote" in location or "Home Office" in location else "No" # default to "No"
        for button in soup.select('button[aria-label]'):
            if "remote" in button.get("aria-label", "").lower():
                remote = "Yes"
                break

        # Search for "Salary Information" only in elements preceding the description
        salary = ""
        if desc_tag:
            # Find all previous elements
            previous_elements = desc_tag.find_all_previous()
            for elem in previous_elements:
                if elem.name == "div" and elem.get("title") == "Salary Information":
                    salary = elem.get_text(strip=True).replace("Salary Icon", "").strip()
                    break

        # Add to batch
        batch.append({
            "Date_Posted": date_posted,
            "Title": title,
            "Company": company,
            "Location": location,
            "Remote": remote,
            "Salary": salary,
            "Keywords": keywords,
            "Description": description,
            "URL": url,
            "Apply_Link": url + "/apply"
        })

        # Write to CSV every batch
        if len(batch) >= BATCH_SIZE:
            pd.DataFrame(batch).to_csv(output_file, mode="a", header=False, index=False)
            total_saved += len(batch)
            print(f"* Saved {len(batch)} job offers to CSV. Total saved: {total_saved} ({total_saved / LIMIT_LINKS * 100:.2f}%)\n")
            batch = []

    except Exception as e:
        print(f"Skipping {url}: {e}")
        continue

# Save remaining data
if batch:
    pd.DataFrame(batch).to_csv(output_file, mode="a", header=False, index=False)
    total_saved += len(batch)
    print(f"* Saved remaining {len(batch)} job offers to CSV. Total saved: {total_saved} ({total_saved / LIMIT_LINKS * 100:.2f}%)\n")

# Close browser after scraping
driver.quit()
end_time = time.time()

# Load the CSV file to count the rows
df = pd.read_csv("arbeitnow_jobs.csv")

# Print summary information
print(f"Total number of saved job offers: {len(df)}")
print(f"Time: {end_time - start_time:.2f} seconds")
# Out:
# Loaded 1074 job links.
# Scraping job offer 1/1074 (0.09%): https://www.arbeitnow.com/jobs/companies/tradelink/solution-consultant-all-genders-munich-448140
# -> API, R
# Scraping job offer 2/1074 (0.19%): https://www.arbeitnow.com/jobs/companies/pathway-solutions-gmbh/senior-backend-devops-engineer-spring-boot-google-cloud-hamburg-141884
# -> API, CI/CD, Cloud, DevOps, GCP, Google Cloud, GraphQL, Java, NoSQL, REST
# Scraping job offer 3/1074 (0.28%): https://www.arbeitnow.com/jobs/companies/lautsprecherteufel/working-student-embedded-testing-berlin-222858
# ----> skipping - no keywords found
# Scraping job offer 4/1074 (0.37%): https://www.arbeitnow.com/jobs/companies/bigrep-gmbh/working-student-it-berlin-82630
# -> AWS, Azure, Cloud
# Scraping job offer 5/1074 (0.47%): https://www.arbeitnow.com/jobs/companies/bigrep-gmbh/working-student-hardware-projects-berlin-150237
# ----> skipping - no keywords found
# Scraping job offer 6/1074 (0.56%): https://www.arbeitnow.com/jobs/companies/justplay-gmbh/head-of-data-all-genders-berlin-441965
# -> Cloud, Docker, GCP, Git, Google Cloud, Python, SQL
# Scraping job offer 7/1074 (0.65%): https://www.arbeitnow.com/jobs/companies/perto-gmbh/working-student-frontend-developer-berlin-18520
# -> API, Agile
# Scraping job offer 8/1074 (0.74%): https://www.arbeitnow.com/jobs/companies/bv-deutsche-zeitungsholding-gmbh-berliner-verlag/senior-back-end-engineer-berlin-167557
# -> AWS, Apache, Cloud, DevOps, MongoDB
# Scraping job offer 9/1074 (0.84%): https://www.arbeitnow.com/jobs/companies/bv-deutsche-zeitungsholding-gmbh-berliner-verlag/senior-front-end-engineer-berlin-345101
# -> Cloud, DevOps
# Scraping job offer 10/1074 (0.93%): https://www.arbeitnow.com/jobs/companies/exmox-gmbh/team-lead-user-acquisition-team-lead-performance-marketing-hamburg-9335
# -> REST
# Scraping job offer 11/1074 (1.02%): https://www.arbeitnow.com/jobs/companies/invia-flights-germany-gmbh/devops-engineer-fluegede-dresden-392490
# -> AWS, Agile, CI/CD, Cloud, DevOps, Docker, Kubernetes
# Scraping job offer 12/1074 (1.12%): https://www.arbeitnow.com/jobs/companies/flix/senior-mobile-engineer-flixtrain-operations-team-berlin-372703
# -> Agile, R
# Scraping job offer 13/1074 (1.21%): https://www.arbeitnow.com/jobs/companies/wolt-english/backend-engineers-python-berlin-43264
# -> AWS, Airflow, CI/CD, Cloud, Data Warehouse, Docker, GitHub, Kubernetes, Machine Learning, Microservices, MongoDB, PostgreSQL, Python, REST
# Scraping job offer 14/1074 (1.30%): https://www.arbeitnow.com/jobs/companies/torg-gmbh/fullstack-developer-berlin-149226
# -> CI/CD, Cloud, Data Engineering, DevOps, Django, Docker, Flask, ML, Python, REST
# Scraping job offer 15/1074 (1.40%): https://www.arbeitnow.com/jobs/companies/coding-partners/full-stack-developer-berlin-166742
# -> AWS, Agile, Algorithms, Azure, CI/CD, Cloud, Django, Flask, GCP, GraphQL, Microservices, MongoDB, PostgreSQL, Python, REST
# Scraping job offer 16/1074 (1.49%): https://www.arbeitnow.com/jobs/companies/progyny-global/qa-engineer-berlin-194929
# -> API, Agile, CI/CD, GitHub, Jira, Python, REST, SQL
# Scraping job offer 17/1074 (1.58%): https://www.arbeitnow.com/jobs/companies/local-brand-x-gmbh/backend-php-developer-remote-freelance-mainz-172781
# -> Git, REST
# Scraping job offer 18/1074 (1.68%): https://www.arbeitnow.com/jobs/companies/softr/senior-growth-marketer-remote-berlin-493680
# ----> skipping - no keywords found
# Scraping job offer 19/1074 (1.77%): https://www.arbeitnow.com/jobs/companies/lindera-gmbh/senior-machine-learning-engineer-ai-integration-engineer-berlin-287213
# -> Algorithms, CI/CD, Deep Learning, DevOps, Docker, Kubernetes, ML, Machine Learning, PyTorch, Python, R, Statistics
# Scraping job offer 20/1074 (1.86%): https://www.arbeitnow.com/jobs/companies/dransay/senior-technical-product-manager-platform-api-integrations-healthcare-remote-berlin-135370
# -> API
# Scraping job offer 21/1074 (1.96%): https://www.arbeitnow.com/jobs/companies/olx/principal-product-manager-genai-based-in-barcelona-berlin-germany-133417
# -> ML, Machine Learning
# Scraping job offer 22/1074 (2.05%): https://www.arbeitnow.com/jobs/companies/olx/principal-data-scientist-pricing-berlin-germany-59954
# -> AWS, Agile, Airflow, Apache, Cloud, Data Engineering, Data Science, Java, ML, Machine Learning, Python, SQL, Spark
# Scraping job offer 23/1074 (2.14%): https://www.arbeitnow.com/jobs/companies/apaleo/staff-engineer-net-munchen-142700
# -> API, AWS, Cloud, Docker, Kubernetes, PostgreSQL, SQL
# Scraping job offer 24/1074 (2.23%): https://www.arbeitnow.com/jobs/companies/hygraph/backend-engineer-remote-emea-berlin-244310
# -> AWS, GitHub, GraphQL, REST
# Scraping job offer 25/1074 (2.33%): https://www.arbeitnow.com/jobs/companies/filestage/junior-software-engineer-remote-europe-stuttgart-93866
# -> AWS, CI/CD, DevOps, Jira, MongoDB
# Scraping job offer 26/1074 (2.42%): https://www.arbeitnow.com/jobs/companies/justwatch/site-reliability-engineer-senior-berlin-281397
# -> Agile, BI, Cloud, Google Cloud, Kubernetes, PostgreSQL, Scrum
# Scraping job offer 27/1074 (2.51%): https://www.arbeitnow.com/jobs/companies/justwatch/devops-engineer-intermediate-senior-berlin-315293
# -> Agile, BI, Cloud, Google Cloud, Kubernetes, PostgreSQL, Scrum
# Scraping job offer 28/1074 (2.61%): https://www.arbeitnow.com/jobs/companies/banking-consult-executive-search/managing-director-corporate-finance-ma-all-genders-frankfurt-395941
# ----> skipping - no keywords found
# Scraping job offer 29/1074 (2.70%): https://www.arbeitnow.com/jobs/companies/quantco/software-engineering-intern-europe-132920
# -> Cloud, Data Science, Java, Python, R
# Scraping job offer 30/1074 (2.79%): https://www.arbeitnow.com/jobs/companies/quantco/software-engineer-berlin-berlin-431354
# -> CI/CD, Data Science, Django, Flask, Pandas, Python, SQL
# Scraping job offer 31/1074 (2.89%): https://www.arbeitnow.com/jobs/companies/quantco/software-engineer-karlsruhe-baden-wurttemberg-242121
# -> Cloud, Data Science, Java, NumPy, Pandas, Python, Scikit-learn
# Scraping job offer 32/1074 (2.98%): https://www.arbeitnow.com/jobs/companies/quantco/software-engineer-munich-bavaria-436687
# -> CI/CD, Data Science, Django, Flask, Pandas, Python, SQL
# Scraping job offer 33/1074 (3.07%): https://www.arbeitnow.com/jobs/companies/netlight/software-engineering-consultant-2024-25-graduate-berlin-146233
# -> Cloud, Data Engineering, DevOps
# Scraping job offer 34/1074 (3.17%): https://www.arbeitnow.com/jobs/companies/landa-corporation/remote-mechanical-integration-specialist-munich-417122
# ----> skipping - no keywords found
# Scraping job offer 35/1074 (3.26%): https://www.arbeitnow.com/jobs/companies/mbagroup/remote-creatorgroup-jobs-marketing-project-manager-en-speaking-for-usoftware-berlin-468540
# ----> skipping - no keywords found
# Scraping job offer 36/1074 (3.35%): https://www.arbeitnow.com/jobs/companies/paintgun/part-time-cto-berlin-236359
# -> Agile, Algorithms, Git, GitHub, GraphQL, Java, MongoDB, REST
# Scraping job offer 37/1074 (3.45%): https://www.arbeitnow.com/jobs/companies/paintgun/creative-producer-at-ad-creative-agency-freelance-berlin-392817
# ----> skipping - no keywords found
# Scraping job offer 38/1074 (3.54%): https://www.arbeitnow.com/jobs/companies/paintgun/ad-creative-strategist-freelance-berlin-36774
# ----> skipping - no keywords found
# Scraping job offer 39/1074 (3.63%): https://www.arbeitnow.com/jobs/companies/sunday/data-scientist-engineer-all-genders-berlin-211623
# -> BI, BigQuery, Cloud, Data Engineering, Data Pipeline, Data Warehouse, ETL, GCP, Google Cloud, Machine Learning, SQL, Tableau
# Scraping job offer 40/1074 (3.72%): https://www.arbeitnow.com/jobs/companies/retailnext/enterprise-account-director-berlin-114252
# -> Cloud
# Scraping job offer 41/1074 (3.82%): https://www.arbeitnow.com/jobs/companies/ventura-travel/epic-trips-brand-director-munich-88355
# -> API
# Scraping job offer 42/1074 (3.91%): https://www.arbeitnow.com/jobs/companies/wolt-english/finance-systems-administrator-developer-ibm-tm1-berlin-139411
# ----> skipping - no keywords found
# Scraping job offer 43/1074 (4.00%): https://www.arbeitnow.com/jobs/companies/markt-pilot/working-student-analytics-engineer-stuttgart-224562
# -> AWS, Agile, Apache, Azure, BI, Cloud, Data Engineering, Data Science, ML, MongoDB, NoSQL, PostgreSQL, Power BI, Python, SQL, Tableau
# Scraping job offer 44/1074 (4.10%): https://www.arbeitnow.com/jobs/companies/qwelloeu/senior-backend-developer-munich-bavaria-452054
# -> AWS, Azure, Cloud, Google Cloud, Python, REST
# Scraping job offer 45/1074 (4.19%): https://www.arbeitnow.com/jobs/companies/fundedclub/senior-back-end-engineer-nodejs-typescript-nestjs-berlin-38774
# -> AWS, CI/CD, Docker, Git, GraphQL, Java, PostgreSQL, Python
# Scraping job offer 46/1074 (4.28%): https://www.arbeitnow.com/jobs/companies/sonar/security-product-manager-bochum-339843
# -> Agile, Cloud
# Scraping job offer 47/1074 (4.38%): https://www.arbeitnow.com/jobs/companies/billie/advanced-analyst-berlin-140843
# -> BI, Data Engineering, ML, Python, R, SQL, Statistics, Tableau
# Scraping job offer 48/1074 (4.47%): https://www.arbeitnow.com/jobs/companies/billie/data-science-analyst-berlin-192781
# -> BI, Data Engineering, Data Science, ML, Python, R, SQL, Statistics, Tableau
# Scraping job offer 49/1074 (4.56%): https://www.arbeitnow.com/jobs/companies/gradle-inc/lead-software-engineer-berlin-314054
# -> Java
# Scraping job offer 50/1074 (4.66%): https://www.arbeitnow.com/jobs/companies/wolt-english/global-catalog-data-quality-manager-berlin-290448
# ----> skipping - no keywords found
# Scraping job offer 51/1074 (4.75%): https://www.arbeitnow.com/jobs/companies/wolt-english/pricing-business-analyst-berlin-41428
# -> ML, Machine Learning, Python, SQL
# Scraping job offer 52/1074 (4.84%): https://www.arbeitnow.com/jobs/companies/wolt-english/senior-manager-international-employee-relations-berlin-107462
# ----> skipping - no keywords found
# Scraping job offer 53/1074 (4.93%): https://www.arbeitnow.com/jobs/companies/conductor-llc/director-of-engineering-berlin-55275
# -> AWS, Agile, CI/CD, Cloud, DevOps, Microservices
# Scraping job offer 54/1074 (5.03%): https://www.arbeitnow.com/jobs/companies/dealfront/remote-ruby-backend-software-engineer-germany-340809
# -> API, AWS, DevOps, Docker, Kubernetes, Microservices
# Scraping job offer 55/1074 (5.12%): https://www.arbeitnow.com/jobs/companies/rapid-pioneers/podcast-host-business-development-manager-berlin-402316
# ----> skipping - no keywords found
# Scraping job offer 56/1074 (5.21%): https://www.arbeitnow.com/jobs/companies/amboss/senior-full-stack-engineer-integrations-berlin-238454
# -> AWS, CI/CD, Docker, GitHub, Kubernetes, Python
# Scraping job offer 57/1074 (5.31%): https://www.arbeitnow.com/jobs/companies/freeletics/senior-backend-developer-all-genders-munich-369207
# -> AWS, Agile, CI/CD, Cloud, DevOps, Docker, GitHub, Kubernetes
# Scraping job offer 58/1074 (5.40%): https://www.arbeitnow.com/jobs/companies/sunday-gmbh/head-of-business-operations-hamburg-271186
# ----> skipping - no keywords found
# Scraping job offer 59/1074 (5.49%): https://www.arbeitnow.com/jobs/companies/sunday-gmbh/business-operations-manager-hamburg-125348
# ----> skipping - no keywords found
# Scraping job offer 60/1074 (5.59%): https://www.arbeitnow.com/jobs/companies/evident-europe-gmbh/quality-assurance-regulatory-affairs-specialist-hamburg-3887
# ----> skipping - no keywords found
# Scraping job offer 61/1074 (5.68%): https://www.arbeitnow.com/jobs/companies/fincite-gmbh/product-owner-innovation-market-data-frankfurt-243990
# -> Agile, Confluence, Jira, Kanban, Scrum
# Scraping job offer 62/1074 (5.77%): https://www.arbeitnow.com/jobs/companies/meet5-gmbh/quality-assurance-engineer-at-meet5-frankfurt-239003
# -> API, Agile, Cloud, Google Cloud, Java, Jira, Python, REST, SQL, Scrum
# Scraping job offer 63/1074 (5.87%): https://www.arbeitnow.com/jobs/companies/virtual-identity-ag/head-of-finance-freiburg-im-breisgau-498231
# ----> skipping - no keywords found
# Scraping job offer 64/1074 (5.96%): https://www.arbeitnow.com/jobs/companies/billie/senior-front-end-engineer-berlin-165552
# -> API, Algorithms, CI/CD, GitHub
# Scraping job offer 65/1074 (6.05%): https://www.arbeitnow.com/jobs/companies/flix/mid-level-java-engineer-team-network-services-berlin-151468
# -> AWS, Agile, Apache, Azure, Cloud, DevOps, Docker, Java, Kubernetes, Microservices, R, REST, SQL
# Scraping job offer 66/1074 (6.15%): https://www.arbeitnow.com/jobs/companies/flix/mid-level-java-engineer-team-network-services-munich-17696
# -> AWS, Agile, Apache, Azure, Cloud, DevOps, Docker, Java, Kubernetes, Microservices, R, REST, SQL
# * Saved 50 job offers to CSV. Total saved: 50 (4.66%)
#
# Scraping job offer 67/1074 (6.24%): https://www.arbeitnow.com/jobs/companies/gharage-vision-hub/senior-project-manager-hamburg-46388
# -> Jira
# Scraping job offer 68/1074 (6.33%): https://www.arbeitnow.com/jobs/companies/de-gier-recruitment-soultions-ltd/system-architect-smart-metering-berlin-332369
# ----> skipping - no keywords found
# Scraping job offer 69/1074 (6.42%): https://www.arbeitnow.com/jobs/companies/sap-leanix/product-enablement-principal-sap-signavio-bonn-344989
# -> SAP
# Scraping job offer 70/1074 (6.52%): https://www.arbeitnow.com/jobs/companies/sap-leanix/senior-product-enablement-specialist-sap-signavio-bonn-487749
# -> Cloud, SAP
# Scraping job offer 71/1074 (6.61%): https://www.arbeitnow.com/jobs/companies/sap-leanix/product-enablement-specialist-sap-signavio-bonn-212877
# -> Cloud, SAP
# Scraping job offer 72/1074 (6.70%): https://www.arbeitnow.com/jobs/companies/sap-leanix/junior-product-enablement-specialist-sap-signavio-bonn-485476
# -> Cloud, SAP
# Scraping job offer 73/1074 (6.80%): https://www.arbeitnow.com/jobs/companies/sap-leanix/senior-product-enablement-specialist-instructional-design-bonn-21044
# -> Agile, SAP
# Scraping job offer 74/1074 (6.89%): https://www.arbeitnow.com/jobs/companies/oncare-gmbh/data-engineer-munich-287916
# -> AWS, Airflow, Apache, Azure, BI, Cloud, Data Engineering, Data Science, Data Visualization, ETL, GCP, NoSQL, Power BI, Python, R, SQL, Spark, Tableau
# Scraping job offer 75/1074 (6.98%): https://www.arbeitnow.com/jobs/companies/bigpoint/senior-unity-developer-5852-hamburg-328660
# -> Java
# Scraping job offer 76/1074 (7.08%): https://www.arbeitnow.com/jobs/companies/bigpoint/senior-java-developer-5851-hamburg-350223
# -> Java
# Scraping job offer 77/1074 (7.17%): https://www.arbeitnow.com/jobs/companies/uai/financial-controller-eggenfelden-66246
# -> BI, Power BI
# Scraping job offer 78/1074 (7.26%): https://www.arbeitnow.com/jobs/companies/amer-sports/sap-fi-co-senior-consultant-garching-99862
# -> Cloud, SAP
# Scraping job offer 79/1074 (7.36%): https://www.arbeitnow.com/jobs/companies/ocell-gmbh/flutter-developer-munich-243421
# -> CI/CD
# Scraping job offer 80/1074 (7.45%): https://www.arbeitnow.com/jobs/companies/evident-europe-gmbh/quality-assurace-regulatory-affairs-specialist-hamburg-122064
# ----> skipping - no keywords found
# Scraping job offer 81/1074 (7.54%): https://www.arbeitnow.com/jobs/companies/evident-europe-gmbh/senior-regulatory-affairs-cybersecurity-ai-manager-clinical-business-hamburg-29402
# -> ML, Machine Learning
# Scraping job offer 82/1074 (7.64%): https://www.arbeitnow.com/jobs/companies/partscloud-gmbh/back-end-engineer-python-75k-based-on-seniority-remote-in-eu-pliezhausen-211470
# -> Algorithms, CI/CD, Cloud, Data Engineering, Data Science, DevOps, Django, Docker, ETL, Linux, ML, Pandas, PostgreSQL, Python, REST
# Scraping job offer 83/1074 (7.73%): https://www.arbeitnow.com/jobs/companies/auto1-group-se/junior-e-mail-marketing-manager-berlin-448829
# ----> skipping - no keywords found
# Scraping job offer 84/1074 (7.82%): https://www.arbeitnow.com/jobs/companies/auto1-group-se/e-mail-marketing-manager-berlin-391876
# ----> skipping - no keywords found
# Scraping job offer 85/1074 (7.91%): https://www.arbeitnow.com/jobs/companies/kotter/principal-professional-services-munich-248205
# ----> skipping - no keywords found
# Scraping job offer 86/1074 (8.01%): https://www.arbeitnow.com/jobs/companies/softgames/senior-unity-game-developer-fully-remote-berlin-334602
# -> CI/CD, GCP
# Scraping job offer 87/1074 (8.10%): https://www.arbeitnow.com/jobs/companies/basilicomgmbh/remote-freelance-senior-frontend-developer-en-berlin-299901
# ----> skipping - no keywords found
# Scraping job offer 88/1074 (8.19%): https://www.arbeitnow.com/jobs/companies/basilicomgmbh/remote-freelance-senior-backend-php-pimcore-developer-en-berlin-121642
# -> GraphQL, REST
# Scraping job offer 89/1074 (8.29%): https://www.arbeitnow.com/jobs/companies/basilicomgmbh/remote-senior-backend-php-pimcore-developer-en-berlin-139885
# -> GraphQL, REST
# Scraping job offer 90/1074 (8.38%): https://www.arbeitnow.com/jobs/companies/tomtom/staff-ii-engineer-software-berlin-germany-448585
# -> Algorithms, Azure, Cloud
# Scraping job offer 91/1074 (8.47%): https://www.arbeitnow.com/jobs/companies/delonghigroup/working-student-rd-laboratory-neu-isenburg-337999
# -> R
# Scraping job offer 92/1074 (8.57%): https://www.arbeitnow.com/jobs/companies/delonghigroup/product-manager-neu-isenburg-339387
# -> Jira
# Scraping job offer 93/1074 (8.66%): https://www.arbeitnow.com/jobs/companies/makersitegmbh/senior-python-backend-engineer-stuttgart-18360
# -> Python, REST
# Scraping job offer 94/1074 (8.75%): https://www.arbeitnow.com/jobs/companies/makersitegmbh/remote-qa-engineer-berlin-429003
# -> Agile, Python
# Scraping job offer 95/1074 (8.85%): https://www.arbeitnow.com/jobs/companies/makersitegmbh/site-reliability-engineer-sre-stuttgart-429019
# ----> skipping - no keywords found
# Scraping job offer 96/1074 (8.94%): https://www.arbeitnow.com/jobs/companies/makersitegmbh/remote-python-backend-engineer-stuttgart-260748
# -> Python, REST
# Scraping job offer 97/1074 (9.03%): https://www.arbeitnow.com/jobs/companies/makersitegmbh/remote-project-manager-team-lead-software-implementations-stuttgart-29627
# ----> skipping - no keywords found
# Scraping job offer 98/1074 (9.12%): https://www.arbeitnow.com/jobs/companies/kpler/full-stack-engineer-germany-149108
# -> Airflow, Cloud, Data Pipeline, Docker, Kubernetes, PostgreSQL, Python
# Scraping job offer 99/1074 (9.22%): https://www.arbeitnow.com/jobs/companies/foodji/remote-golang-developer-all-genders-munchen-391823
# -> API, AWS, Cloud, Docker, GitHub, Machine Learning, MongoDB, Python, REST
# Scraping job offer 100/1074 (9.31%): https://www.arbeitnow.com/jobs/companies/toloka-ai/remote-freelance-software-developer-cli-ai-tutor-berlin-162682
# -> Bitbucket, DevOps, Docker, Git, GitHub, Kubernetes, Python
# Scraping job offer 101/1074 (9.40%): https://www.arbeitnow.com/jobs/companies/toloka-ai/remote-freelance-software-developer-cli-ai-tutor-germany-457781
# -> Bitbucket, DevOps, Docker, Git, GitHub, Kubernetes, Python
# Scraping job offer 102/1074 (9.50%): https://www.arbeitnow.com/jobs/companies/threecolts/lead-product-manager-e-commerce-seller-tools-berlin-137618
# -> API, Agile
# Scraping job offer 103/1074 (9.59%): https://www.arbeitnow.com/jobs/companies/smartcat/remote-pre-sales-consultant-454413
# -> API, Machine Learning, Python, REST, Statistics
# Scraping job offer 104/1074 (9.68%): https://www.arbeitnow.com/jobs/companies/flix/crm-operations-manager-berlin-399443
# -> API
# Scraping job offer 105/1074 (9.78%): https://www.arbeitnow.com/jobs/companies/transparent-hiring/shelf-planning-expert-sme-dusseldorf-299124
# -> SAP, SQL
# Scraping job offer 106/1074 (9.87%): https://www.arbeitnow.com/jobs/companies/transparent-hiring/retail-merchandising-systems-expert-sme-dusseldorf-456793
# -> SAP, SQL
# Scraping job offer 107/1074 (9.96%): https://www.arbeitnow.com/jobs/companies/quantumsystemsgmbh/software-developer-swarming-gilching-306023
# -> Algorithms, Linux, ML
# Scraping job offer 108/1074 (10.06%): https://www.arbeitnow.com/jobs/companies/quantumsystemsgmbh/embedded-software-test-engineer-gilching-402170
# ----> skipping - no keywords found
# Scraping job offer 109/1074 (10.15%): https://www.arbeitnow.com/jobs/companies/quantumsystemsgmbh/simulation-software-engineer-c-gilching-267278
# ----> skipping - no keywords found
# Scraping job offer 110/1074 (10.24%): https://www.arbeitnow.com/jobs/companies/transparent-hiring/qa-engineer-it-supply-chain-dusseldorf-104331
# -> Agile, Jira, REST
# Scraping job offer 111/1074 (10.34%): https://www.arbeitnow.com/jobs/companies/transparent-hiring/russian-speaking-job-sourcer-remote-munich-52052
# -> Java
# Scraping job offer 112/1074 (10.43%): https://www.arbeitnow.com/jobs/companies/transparent-hiring/data-governance-kpi-consultant-dusseldorf-146630
# -> BI, Tableau
# Scraping job offer 113/1074 (10.52%): https://www.arbeitnow.com/jobs/companies/ubitricity-gesellschaft-fur-verteilte-energiesysteme-mbh/commercial-controller-berlin-390190
# -> Agile, BI, Business Intelligence, Power BI, Tableau
# Scraping job offer 114/1074 (10.61%): https://www.arbeitnow.com/jobs/companies/stabl-energy/battery-integration-engineer-munich-225132
# -> Agile, Spark
# Scraping job offer 115/1074 (10.71%): https://www.arbeitnow.com/jobs/companies/auto1-group-se/senior-data-scientist-berlin-381478
# -> AWS, Azure, Cloud, Data Science, Deep Learning, Google Cloud, Machine Learning, PyTorch, Python, SQL
# Scraping job offer 116/1074 (10.80%): https://www.arbeitnow.com/jobs/companies/zapdeck/student-ai-engineer-finetuning-llms-20-hours-week-berlin-236242
# -> Data Science, PyTorch
# Scraping job offer 117/1074 (10.89%): https://www.arbeitnow.com/jobs/companies/techbizglobal/remote-senior-go-software-engineer-aachen-32606
# ----> skipping - no keywords found
# Scraping job offer 118/1074 (10.99%): https://www.arbeitnow.com/jobs/companies/techbizglobal/remote-senior-go-developer-real-time-voice-telephony-ai-aachen-382385
# ----> skipping - no keywords found
# Scraping job offer 119/1074 (11.08%): https://www.arbeitnow.com/jobs/companies/hexagon/software-project-engineer-all-gender-garching-305178
# ----> skipping - no keywords found
# Scraping job offer 120/1074 (11.17%): https://www.arbeitnow.com/jobs/companies/orbem/product-manager-team-lead-core-munchen-411780
# ----> skipping - no keywords found
# Scraping job offer 121/1074 (11.27%): https://www.arbeitnow.com/jobs/companies/lumas/kopie-von-frontend-engineer-berlin-headquarter-107360
# -> AWS, Agile, Azure, CI/CD, Cloud, GCP, GraphQL, Kanban, Scrum
# Scraping job offer 122/1074 (11.36%): https://www.arbeitnow.com/jobs/companies/penumbra/office-manager-temporary-position-working-student-berlin-43643
# ----> skipping - no keywords found
# Scraping job offer 123/1074 (11.45%): https://www.arbeitnow.com/jobs/companies/sunday-gmbh/marketing-intern-hamburg-427890
# ----> skipping - no keywords found
# Scraping job offer 124/1074 (11.55%): https://www.arbeitnow.com/jobs/companies/billie/mid-devops-engineer-berlin-215115
# -> AWS, CI/CD, Cloud, DevOps, Java, Kubernetes, Python
# Scraping job offer 125/1074 (11.64%): https://www.arbeitnow.com/jobs/companies/flix/senior-java-engineer-team-financial-services-munchen-449277
# -> AWS, Agile, Apache, Cloud, DevOps, Docker, Java, Kubernetes, Microservices, R
# Scraping job offer 126/1074 (11.73%): https://www.arbeitnow.com/jobs/companies/ventura-travel/travel-intrapreneur-start-your-own-travel-brand-middle-east-and-north-africa-berlin-207266
# ----> skipping - no keywords found
# Scraping job offer 127/1074 (11.82%): https://www.arbeitnow.com/jobs/companies/ventura-travel/travel-intrapreneur-start-your-own-travel-brand-students-exchange-berlin-402475
# ----> skipping - no keywords found
# Scraping job offer 128/1074 (11.92%): https://www.arbeitnow.com/jobs/companies/ventura-travel/travel-intrapreneur-travel-with-a-disability-berlin-287533
# ----> skipping - no keywords found
# Scraping job offer 129/1074 (12.01%): https://www.arbeitnow.com/jobs/companies/one-thousand-gmbh/machine-learning-engineer-berlin-196327
# -> API, Azure, Cloud, Data Science, Docker, ML, Machine Learning, Matplotlib, Pandas, PostgreSQL, PyTorch, Python, SAP, SQL, Scikit-learn, TensorFlow
# Scraping job offer 130/1074 (12.10%): https://www.arbeitnow.com/jobs/companies/wikimedia-deutschland-ev/staff-engineer-wikidata-all-genders-berlin-179812
# -> Git
# Scraping job offer 131/1074 (12.20%): https://www.arbeitnow.com/jobs/companies/flummox/jr-ppc-analyst-remote-at-group-of-e-commerce-brands-berlin-285773
# ----> skipping - no keywords found
# Scraping job offer 132/1074 (12.29%): https://www.arbeitnow.com/jobs/companies/deep-neuron-lab/senior-backend-engineer-building-scalable-ai-systems-berlin-192907
# -> Azure, CI/CD, Cloud, Flask, Kubernetes, Machine Learning, Microservices, Python
# Scraping job offer 133/1074 (12.38%): https://www.arbeitnow.com/jobs/companies/koro-handels-gmbh/fpa-analyst-berlin-75875
# -> BigQuery, Data Visualization, SAP, Tableau
# Scraping job offer 134/1074 (12.48%): https://www.arbeitnow.com/jobs/companies/lufthansa-innovation-hub-gmbh/co-founder-cto-at-ai-logistics-venture-all-genders-berlin-189927
# -> API, DevOps, Java, Python
# Scraping job offer 135/1074 (12.57%): https://www.arbeitnow.com/jobs/companies/market-cloud/sap-gts-consultant-eschborn-146433
# -> Cloud, SAP
# Scraping job offer 136/1074 (12.66%): https://www.arbeitnow.com/jobs/companies/braineffect/team-lead-influencer-marketing-france-french-speaking-berlin-345260
# ----> skipping - no keywords found
# Scraping job offer 137/1074 (12.76%): https://www.arbeitnow.com/jobs/companies/mycashbacks-gmbh/working-student-portal-manager-for-italy-and-spain-berlin-128185
# ----> skipping - no keywords found
# Scraping job offer 138/1074 (12.85%): https://www.arbeitnow.com/jobs/companies/machinelearningreply/software-engineer-munchen-446716
# -> AWS, Azure, BI, Cloud, Data Engineering, Data Science, DevOps, Flask, GCP, Java, Machine Learning, Python
# * Saved 50 job offers to CSV. Total saved: 100 (9.31%)
#
# Scraping job offer 139/1074 (12.94%): https://www.arbeitnow.com/jobs/companies/machinelearningreply/cloud-and-data-engineer-munich-137579
# -> AWS, Algorithms, Azure, BI, Cloud, Data Engineering, Data Science, GCP, Machine Learning
# Scraping job offer 140/1074 (13.04%): https://www.arbeitnow.com/jobs/companies/flaconi/working-student-pricing-all-genders-berlin-charlottenburg-111055
# ----> skipping - no keywords found
# Scraping job offer 141/1074 (13.13%): https://www.arbeitnow.com/jobs/companies/flaconi/junior-customer-service-agent-french-market-all-genders-berlin-charlottenburg-407980
# ----> skipping - no keywords found
# Scraping job offer 142/1074 (13.22%): https://www.arbeitnow.com/jobs/companies/flaconi/financial-controller-all-genders-berlin-charlottenburg-399148
# -> BI
# Scraping job offer 143/1074 (13.31%): https://www.arbeitnow.com/jobs/companies/flaconi/engineering-manager-mobile-all-genders-berlin-charlottenburg-289724
# -> AWS, Agile, CI/CD, Cloud
# Scraping job offer 144/1074 (13.41%): https://www.arbeitnow.com/jobs/companies/flaconi/country-manager-belgium-netherlands-all-genders-berlin-charlottenburg-87104
# ----> skipping - no keywords found
# Scraping job offer 145/1074 (13.50%): https://www.arbeitnow.com/jobs/companies/applike/software-developer-working-student-hamburg-448584
# -> AWS, Algorithms, Java, Machine Learning, Microservices
# Scraping job offer 146/1074 (13.59%): https://www.arbeitnow.com/jobs/companies/applike/senior-go-backend-developer-hamburg-197501
# -> API, Algorithms, BI, Data Lake, Data Science, Docker, ML, Machine Learning
# Scraping job offer 147/1074 (13.69%): https://www.arbeitnow.com/jobs/companies/applike/senior-data-scientist-hamburg-43725
# -> AWS, Algorithms, Data Pipeline, Data Science, ML, Python, SQL, Scikit-learn, Spark
# Scraping job offer 148/1074 (13.78%): https://www.arbeitnow.com/jobs/companies/applike/devops-engineer-hamburg-253943
# -> AWS, Airflow, CI/CD, Cloud, DevOps, Kubernetes, NoSQL, SQL, Spark
# Scraping job offer 149/1074 (13.87%): https://www.arbeitnow.com/jobs/companies/peter-park/remote-lead-devops-engineer-157634
# -> AWS, Agile, CI/CD, Cloud, DevOps, Docker, Kubernetes, Python
# Scraping job offer 150/1074 (13.97%): https://www.arbeitnow.com/jobs/companies/ororatech-gmbh/software-engineer-wildfire-impact-recovery-munich-80254
# -> Agile, Airflow, Algorithms, CI/CD, Cloud, Docker, Git, NumPy, Pandas, Python, R, SQL
# Scraping job offer 151/1074 (14.06%): https://www.arbeitnow.com/jobs/companies/billie/data-engineer-with-flink-berlin-468608
# -> AWS, Airflow, Cloud, Data Engineering
# Scraping job offer 152/1074 (14.15%): https://www.arbeitnow.com/jobs/companies/flix/crm-communications-manager-munich-56903
# -> SQL
# Scraping job offer 153/1074 (14.25%): https://www.arbeitnow.com/jobs/companies/flix/senior-ui-ux-designer-flixtrain-operations-management-team-berlin-493016
# -> R
# Scraping job offer 154/1074 (14.34%): https://www.arbeitnow.com/jobs/companies/alrdy/web-designer-remote-berlin-311235
# ----> skipping - no keywords found
# Scraping job offer 155/1074 (14.43%): https://www.arbeitnow.com/jobs/companies/auto1-group-se/google-apps-script-engineer-berlin-296907
# -> Git, Python, SQL
# Scraping job offer 156/1074 (14.53%): https://www.arbeitnow.com/jobs/companies/auto1-group-se/junior-google-apps-script-engineer-berlin-476311
# -> Git, Python, SQL
# Scraping job offer 157/1074 (14.62%): https://www.arbeitnow.com/jobs/companies/green-fusion-gmbh/working-student-for-it-data-operations-berlin-277842
# -> Cloud, Git, GitHub, Jira, SQL
# Scraping job offer 158/1074 (14.71%): https://www.arbeitnow.com/jobs/companies/simi-reality-motion-systems-gmbh/software-engineer-python-unterschleissheim-114996
# -> CI/CD, Git, Linux, Machine Learning, Python
# Scraping job offer 159/1074 (14.80%): https://www.arbeitnow.com/jobs/companies/jungvonmatt/senior-frontend-developer-berlin-383294
# -> AWS, Azure, Cloud, GitHub, Java
# Scraping job offer 160/1074 (14.90%): https://www.arbeitnow.com/jobs/companies/propellerhead/move-to-new-zealand-product-owner-berlin-68843
# -> Agile
# Scraping job offer 161/1074 (14.99%): https://www.arbeitnow.com/jobs/companies/justtrack/devops-engineer-hamburg-243999
# -> AWS, Airflow, CI/CD, Cloud, DevOps, Kubernetes, NoSQL, SQL, Spark
# Scraping job offer 162/1074 (15.08%): https://www.arbeitnow.com/jobs/companies/flix/customer-service-project-manager-berlin-389387
# -> BI, Confluence, Jira, Power BI, Tableau
# Scraping job offer 163/1074 (15.18%): https://www.arbeitnow.com/jobs/companies/score4more-gmbh/senior-fullstack-developer-engineer-python-react-typescript-nlp-esg-main-residence-germany-berlin-27329
# -> API, AWS, Agile, CI/CD, Cloud, DevOps, Docker, GraphQL, Kanban, Kubernetes, ML, Machine Learning, NLP, PostgreSQL, Python, REST, Scrum
# Scraping job offer 164/1074 (15.27%): https://www.arbeitnow.com/jobs/companies/flip-gmbh/quality-assistance-engineer-berlin-95659
# -> API, BI
# Scraping job offer 165/1074 (15.36%): https://www.arbeitnow.com/jobs/companies/enway/embedded-software-engineering-intern-autonomous-street-sweeper-development-berlin-225998
# ----> skipping - no keywords found
# Scraping job offer 166/1074 (15.46%): https://www.arbeitnow.com/jobs/companies/ekvip-automation-gmbh/automation-service-technician-leipzig-111100
# ----> skipping - no keywords found
# Scraping job offer 167/1074 (15.55%): https://www.arbeitnow.com/jobs/companies/punku-gmbh/ai-swe-heilbronn-400121
# -> AWS, Cloud, Python
# Scraping job offer 168/1074 (15.64%): https://www.arbeitnow.com/jobs/companies/chaos/remote-software-developer-cnet-karlsruhe-453736
# ----> skipping - no keywords found
# Scraping job offer 169/1074 (15.74%): https://www.arbeitnow.com/jobs/companies/understandai/senior-full-stack-software-engineer-all-genders-karlsruhe-hq-201277
# -> Agile, Cloud, DevOps, Docker, Google Cloud, Kubernetes, ML, MongoDB, PostgreSQL, Python
# Scraping job offer 170/1074 (15.83%): https://www.arbeitnow.com/jobs/companies/1komma50/senior-software-engineer-control-berlin-192191
# -> Agile, Algorithms, CI/CD, Cloud, DevOps, Linux, Python
# Scraping job offer 171/1074 (15.92%): https://www.arbeitnow.com/jobs/companies/deck-13-interactive-gmbh/senior-gameplay-programmer-frankfurt-361834
# -> Python
# Scraping job offer 172/1074 (16.01%): https://www.arbeitnow.com/jobs/companies/deck-13-interactive-gmbh/senior-combat-designer-frankfurt-230777
# ----> skipping - no keywords found
# Scraping job offer 173/1074 (16.11%): https://www.arbeitnow.com/jobs/companies/trocknerheld-wasserschadensanierung-gmbh/chief-technology-officer-cto-berlin-122460
# -> Machine Learning
# Scraping job offer 174/1074 (16.20%): https://www.arbeitnow.com/jobs/companies/bolt-technology/staff-data-scientist-delivery-berlin-germany-36389
# -> AWS, Airflow, Data Science, Deep Learning, Docker, ML, Machine Learning, NumPy, Pandas, PyTorch, Python, Scikit-learn, Spark
# Scraping job offer 175/1074 (16.29%): https://www.arbeitnow.com/jobs/companies/bolt-technology/senior-marketplace-analyst-ride-hailing-berlin-395879
# -> Algorithms, BI, Data Science, Python, R, SQL, Statistics
# Scraping job offer 176/1074 (16.39%): https://www.arbeitnow.com/jobs/companies/bolt-technology/senior-data-scientist-campaigns-berlin-241950
# -> Airflow, Data Science, Docker, Machine Learning, Python, SQL, Statistics
# Scraping job offer 177/1074 (16.48%): https://www.arbeitnow.com/jobs/companies/bolt-technology/fleet-operations-driver-mannheim-404275
# ----> skipping - no keywords found
# Scraping job offer 178/1074 (16.57%): https://www.arbeitnow.com/jobs/companies/retailnext/remote-revenue-accounting-manager-375338
# -> BI, Power BI
# Scraping job offer 179/1074 (16.67%): https://www.arbeitnow.com/jobs/companies/ventura-travel/epic-trips-brand-director-berlin-379723
# -> API
# Scraping job offer 180/1074 (16.76%): https://www.arbeitnow.com/jobs/companies/ventura-travel/travel-intrapreneur-start-your-own-travel-brand-bike-tours-berlin-448746
# ----> skipping - no keywords found
# Scraping job offer 181/1074 (16.85%): https://www.arbeitnow.com/jobs/companies/buycycle/product-manager-marketplace-all-genders-munchen-203794
# ----> skipping - no keywords found
# Scraping job offer 182/1074 (16.95%): https://www.arbeitnow.com/jobs/companies/egym-gmbh/senior-frontend-engineer-germany-berlin-7783
# -> API, CI/CD, Java, Kubernetes
# Scraping job offer 183/1074 (17.04%): https://www.arbeitnow.com/jobs/companies/mirakl/enterprise-account-executive-retail-media-munich-179184
# ----> skipping - no keywords found
# Scraping job offer 184/1074 (17.13%): https://www.arbeitnow.com/jobs/companies/mirakl/senior-enterprise-account-manager-dach-munich-440551
# ----> skipping - no keywords found
# Scraping job offer 185/1074 (17.23%): https://www.arbeitnow.com/jobs/companies/arbio/remote-recruiting-working-student-berlin-83678
# ----> skipping - no keywords found
# Scraping job offer 186/1074 (17.32%): https://www.arbeitnow.com/jobs/companies/caremates/werkstudent-software-engineer-fullstack-munich-147150
# -> AWS, Agile, Cloud, Python
# Scraping job offer 187/1074 (17.41%): https://www.arbeitnow.com/jobs/companies/acuitymd/remote-product-marketing-manager-144326
# -> REST
# Scraping job offer 188/1074 (17.50%): https://www.arbeitnow.com/jobs/companies/alokai/remote-alokai-future-career-opportunities-327917
# -> REST
# Scraping job offer 189/1074 (17.60%): https://www.arbeitnow.com/jobs/companies/united-media/private-equity-volunteer-munich-337868
# ----> skipping - no keywords found
# Scraping job offer 190/1074 (17.69%): https://www.arbeitnow.com/jobs/companies/united-media/pei-munich-volunteer-programme-387417
# ----> skipping - no keywords found
# Scraping job offer 191/1074 (17.78%): https://www.arbeitnow.com/jobs/companies/united-media/management-consulting-volunteer-munich-45343
# ----> skipping - no keywords found
# Scraping job offer 192/1074 (17.88%): https://www.arbeitnow.com/jobs/companies/united-media/investment-banking-volunteer-munich-203565
# ----> skipping - no keywords found
# Scraping job offer 193/1074 (17.97%): https://www.arbeitnow.com/jobs/companies/united-media/event-volunteer-munich-166060
# ----> skipping - no keywords found
# Scraping job offer 194/1074 (18.06%): https://www.arbeitnow.com/jobs/companies/tulip-interfaces/regional-sales-lead-munich-44487
# -> Cloud
# Scraping job offer 195/1074 (18.16%): https://www.arbeitnow.com/jobs/companies/billie/data-engineer-flink-berlin-367880
# -> AWS, Airflow, Cloud, Data Engineering
# Scraping job offer 196/1074 (18.25%): https://www.arbeitnow.com/jobs/companies/ventura-travel/market-entry-director-berlin-104651
# ----> skipping - no keywords found
# Scraping job offer 197/1074 (18.34%): https://www.arbeitnow.com/jobs/companies/ventura-travel/travel-intrapreneur-start-your-own-travel-brand-medical-tourism-berlin-459427
# ----> skipping - no keywords found
# Scraping job offer 198/1074 (18.44%): https://www.arbeitnow.com/jobs/companies/ventura-travel/travel-intrapreneur-trekking-tours-berlin-127284
# ----> skipping - no keywords found
# Scraping job offer 199/1074 (18.53%): https://www.arbeitnow.com/jobs/companies/ventura-travel/travel-intrapreneur-start-your-own-travel-brand-central-asia-tours-berlin-322017
# ----> skipping - no keywords found
# Scraping job offer 200/1074 (18.62%): https://www.arbeitnow.com/jobs/companies/ventura-travel/travel-intrapreneur-start-your-own-travel-brand-scandinavia-travel-berlin-24875
# ----> skipping - no keywords found
# Scraping job offer 201/1074 (18.72%): https://www.arbeitnow.com/jobs/companies/ventura-travel/travel-intrapreneur-start-your-own-travel-brand-family-trips-berlin-438347
# ----> skipping - no keywords found
# Scraping job offer 202/1074 (18.81%): https://www.arbeitnow.com/jobs/companies/ventura-travel/start-your-own-travel-brand-for-usa-and-canada-berlin-325969
# ----> skipping - no keywords found
# Scraping job offer 203/1074 (18.90%): https://www.arbeitnow.com/jobs/companies/ventura-travel/spontaneous-application-berlin-180637
# ----> skipping - no keywords found
# Scraping job offer 204/1074 (18.99%): https://www.arbeitnow.com/jobs/companies/ventura-travel/travel-specialist-for-japan-fr-market-berlin-177376
# ----> skipping - no keywords found
# Scraping job offer 205/1074 (19.09%): https://www.arbeitnow.com/jobs/companies/ventura-travel/start-your-own-travel-brand-for-india-nepal-sri-lanka-berlin-447339
# ----> skipping - no keywords found
# Scraping job offer 206/1074 (19.18%): https://www.arbeitnow.com/jobs/companies/ventura-travel/travel-intrapreneur-start-your-own-travel-brand-berlin-429889
# ----> skipping - no keywords found
# Scraping job offer 207/1074 (19.27%): https://www.arbeitnow.com/jobs/companies/wolt-english/staff-engineer-consumer-group-berlin-127394
# -> Kubernetes, MongoDB, PostgreSQL, Python
# Scraping job offer 208/1074 (19.37%): https://www.arbeitnow.com/jobs/companies/conductor-llc/senior-devops-engineer-berlin-17175
# -> AWS, CI/CD, Cloud, DevOps, GitHub, Kubernetes, Linux, Microservices
# Scraping job offer 209/1074 (19.46%): https://www.arbeitnow.com/jobs/companies/conductor-llc/senior-software-engineer-ii-php-web-monitoring-berlin-401671
# -> AWS
# Scraping job offer 210/1074 (19.55%): https://www.arbeitnow.com/jobs/companies/conductor-llc/principal-product-manager-conductor-website-monitoring-berlin-172693
# -> Web Crawling
# Scraping job offer 211/1074 (19.65%): https://www.arbeitnow.com/jobs/companies/auto1-group-se/senior-talent-acquisition-business-analyst-berlin-32943
# ----> skipping - no keywords found
# Scraping job offer 212/1074 (19.74%): https://www.arbeitnow.com/jobs/companies/babbel/senior-learning-development-manager-all-genders-berlin-142993
# ----> skipping - no keywords found
# Scraping job offer 213/1074 (19.83%): https://www.arbeitnow.com/jobs/companies/paltron-gmbh/teamlead-data-engineering-hamburg-24716
# -> Agile, Azure, Cloud, Data Engineering, Data Science, Machine Learning
# Scraping job offer 214/1074 (19.93%): https://www.arbeitnow.com/jobs/companies/doneberlin/global-director-sales-retail-media-monetization-at-avolta-berlin-252730
# ----> skipping - no keywords found
# Scraping job offer 215/1074 (20.02%): https://www.arbeitnow.com/jobs/companies/spellfusion-gmbh/internship-game-2d-concept-artist-for-rogue-like-deckbuilding-game-cologne-333902
# ----> skipping - no keywords found
# Scraping job offer 216/1074 (20.11%): https://www.arbeitnow.com/jobs/companies/simpleclub/product-designer-remote-munich-156500
# ----> skipping - no keywords found
# Scraping job offer 217/1074 (20.20%): https://www.arbeitnow.com/jobs/companies/bolt-technology/staff-product-designer-logistics-berlin-germany-469568
# -> Confluence, Jira
# Scraping job offer 218/1074 (20.30%): https://www.arbeitnow.com/jobs/companies/bolt-technology/staff-product-designer-logistics-berlin-germany-470668
# -> Confluence, Jira
# Scraping job offer 219/1074 (20.39%): https://www.arbeitnow.com/jobs/companies/bolt-technology/senior-product-designer-rides-berlin-453745
# -> Confluence, Jira
# Scraping job offer 220/1074 (20.48%): https://www.arbeitnow.com/jobs/companies/simplesurance/qa-automation-engineer-all-genders-berlin-germany-42619
# -> AWS, Cloud, GCP, GitHub, Linux
# Scraping job offer 221/1074 (20.58%): https://www.arbeitnow.com/jobs/companies/wolt-english/strategy-operations-manager-growth-marketing-berlin-226222
# -> SQL
# Scraping job offer 222/1074 (20.67%): https://www.arbeitnow.com/jobs/companies/wolt-english/merchant-gear-associate-berlin-474117
# ----> skipping - no keywords found
# Scraping job offer 223/1074 (20.76%): https://www.arbeitnow.com/jobs/companies/carly/quality-assurance-qa-manager-munich-44631
# -> API, Agile, CI/CD
# Scraping job offer 224/1074 (20.86%): https://www.arbeitnow.com/jobs/companies/pink-frog/adtech-engineer-berlin-127469
# ----> skipping - no keywords found
# Scraping job offer 225/1074 (20.95%): https://www.arbeitnow.com/jobs/companies/justdice-gmbh/user-acquisition-manager-hamburg-70173
# ----> skipping - no keywords found
# Scraping job offer 226/1074 (21.04%): https://www.arbeitnow.com/jobs/companies/dlthub/working-student-solutions-engineering-berlin-77392
# -> Data Engineering, ETL, Machine Learning, Python, SQL
# * Saved 50 job offers to CSV. Total saved: 150 (13.97%)
#
# Scraping job offer 227/1074 (21.14%): https://www.arbeitnow.com/jobs/companies/dlthub/senior-software-engineer-python-oss-berlin-131734
# -> AWS, BigQuery, CI/CD, Data Engineering, Data Science, DevOps, Docker, GCP, GitHub, Kubernetes, Machine Learning, Python, SQL
# Scraping job offer 228/1074 (21.23%): https://www.arbeitnow.com/jobs/companies/beducated-gmbh/website-content-assistant-freelance-contractor-munich-333707
# -> Jira
# Scraping job offer 229/1074 (21.32%): https://www.arbeitnow.com/jobs/companies/doneberlin/full-stack-engineer-hamburg-175082
# -> Agile, CI/CD, Cloud, DevOps, Docker, GCP, Git, Java, Linux, Microservices, MongoDB, PostgreSQL, Python
# Scraping job offer 230/1074 (21.42%): https://www.arbeitnow.com/jobs/companies/smartmicro/hardware-developer-braunschweig-460055
# ----> skipping - no keywords found
# Scraping job offer 231/1074 (21.51%): https://www.arbeitnow.com/jobs/companies/distribusion/remote-senior-python-software-engineer-all-genders-berlin-399055
# -> Python
# Scraping job offer 232/1074 (21.60%): https://www.arbeitnow.com/jobs/companies/distribusion/remote-senior-frontend-engineer-all-genders-berlin-9785
# ----> skipping - no keywords found
# Scraping job offer 233/1074 (21.69%): https://www.arbeitnow.com/jobs/companies/everest-carbon/head-of-rd-berlin-261603
# -> R
# Scraping job offer 234/1074 (21.79%): https://www.arbeitnow.com/jobs/companies/everest-carbon/technician-sensor-electronics-berlin-82396
# -> R
# Scraping job offer 235/1074 (21.88%): https://www.arbeitnow.com/jobs/companies/tucows-inc/market-development-manager-bonn-392576
# ----> skipping - no keywords found
# Scraping job offer 236/1074 (21.97%): https://www.arbeitnow.com/jobs/companies/leverdemo-8/data-scientist-berlin-germany-103944
# -> Python, SQL
# Scraping job offer 237/1074 (22.07%): https://www.arbeitnow.com/jobs/companies/projekt-3t-gmbh/director-software-engineering-practice-architecture-dusseldorf-182557
# -> Agile, Cloud, DevOps, SAP
# Scraping job offer 238/1074 (22.16%): https://www.arbeitnow.com/jobs/companies/cyanite/working-student-in-content-marketing-berlin-378186
# ----> skipping - no keywords found
# Scraping job offer 239/1074 (22.25%): https://www.arbeitnow.com/jobs/companies/cyanite/fullstack-developer-berlin-223772
# -> API, AWS, Cloud, Docker, GitHub, GraphQL, Kubernetes, Microservices, Python, REST
# Scraping job offer 240/1074 (22.35%): https://www.arbeitnow.com/jobs/companies/lumiform/senior-product-designer-all-genders-berlin-380767
# ----> skipping - no keywords found
# Scraping job offer 241/1074 (22.44%): https://www.arbeitnow.com/jobs/companies/koro-handels-gmbh/backend-php-integrations-engineer-berlin-455134
# -> API
# Scraping job offer 242/1074 (22.53%): https://www.arbeitnow.com/jobs/companies/meet5-gmbh/senior-backend-developer-at-meet5-frankfurt-102522
# -> Algorithms, BigQuery, Cloud, GCP, GitHub, Google Cloud, Java, NoSQL, REST, SQL
# Scraping job offer 243/1074 (22.63%): https://www.arbeitnow.com/jobs/companies/ai-omatic-solutions-gmbh/fullstack-developer-all-genders-hamburg-4666
# -> Azure, CI/CD, GitHub, Jira, Python, SQL
# Scraping job offer 244/1074 (22.72%): https://www.arbeitnow.com/jobs/companies/k-tronik-gmbh/development-engineer-for-pld-fpga-lindenberg-313116
# -> Python
# Scraping job offer 245/1074 (22.81%): https://www.arbeitnow.com/jobs/companies/audiencly-gmbh/financial-coordinator-part-time-dusseldorf-46840
# -> BI, Power BI
# Scraping job offer 246/1074 (22.91%): https://www.arbeitnow.com/jobs/companies/yfood-labs-gmbh/trade-marketing-manager-accelerating-emerging-markets-munich-425013
# ----> skipping - no keywords found
# Scraping job offer 247/1074 (23.00%): https://www.arbeitnow.com/jobs/companies/memfault/full-stack-engineer-typescript-python-berlin-germany-new-york-ny-boston-ma-327446
# -> AWS, Cloud, Django, Docker, Flask, PostgreSQL, Python
# Scraping job offer 248/1074 (23.09%): https://www.arbeitnow.com/jobs/companies/meet5-gmbh/senior-performance-marketing-manager-at-meet5-frankfurt-388652
# ----> skipping - no keywords found
# Scraping job offer 249/1074 (23.18%): https://www.arbeitnow.com/jobs/companies/wolt-english/product-lead-autonomous-deliveries-berlin-92725
# ----> skipping - no keywords found
# Scraping job offer 250/1074 (23.28%): https://www.arbeitnow.com/jobs/companies/meet5-gmbh/community-manager-for-meet5-usa-frankfurt-55657
# ----> skipping - no keywords found
# Scraping job offer 251/1074 (23.37%): https://www.arbeitnow.com/jobs/companies/exmox-gmbh/senior-fullstack-engineer-hamburg-145203
# -> API, Docker, GraphQL, Kubernetes, Python, REST
# Scraping job offer 252/1074 (23.46%): https://www.arbeitnow.com/jobs/companies/exmox-gmbh/senior-product-manager-hamburg-140199
# -> Agile, REST
# Scraping job offer 253/1074 (23.56%): https://www.arbeitnow.com/jobs/companies/auto1-group-se/working-student-data-science-berlin-266181
# -> Data Science, Deep Learning, ML, Machine Learning, Python, SQL
# Scraping job offer 254/1074 (23.65%): https://www.arbeitnow.com/jobs/companies/exmox-gmbh/senior-ui-ux-designer-product-designer-hamburg-137362
# -> Agile, REST
# Scraping job offer 255/1074 (23.74%): https://www.arbeitnow.com/jobs/companies/atmen/auditor-sustainability-expert-green-compliance-at-atmen-munich-446492
# -> Data Science
# Scraping job offer 256/1074 (23.84%): https://www.arbeitnow.com/jobs/companies/nfinite/3d-modeler-limburg-314017
# -> R
# Scraping job offer 257/1074 (23.93%): https://www.arbeitnow.com/jobs/companies/soonamiio-gmbh/marketing-assistant-intern-berlin-208469
# ----> skipping - no keywords found
# Scraping job offer 258/1074 (24.02%): https://www.arbeitnow.com/jobs/companies/fundedclub/fpga-engineer-processor-emulation-karlsruhe-272303
# ----> skipping - no keywords found
# Scraping job offer 259/1074 (24.12%): https://www.arbeitnow.com/jobs/companies/tooltime-gmbh/product-manager-part-time-80-partnerships-squad-berlin-319322
# -> REST
# Scraping job offer 260/1074 (24.21%): https://www.arbeitnow.com/jobs/companies/justwatch/senior-bi-developer-streaming-guide-berlin-97911
# -> Airflow, BI, Power BI, SQL, Tableau
# Scraping job offer 261/1074 (24.30%): https://www.arbeitnow.com/jobs/companies/netlight/working-student-talent-growth-hamburg-341484
# ----> skipping - no keywords found
# Scraping job offer 262/1074 (24.39%): https://www.arbeitnow.com/jobs/companies/finn/senior-data-scientist-pricing-munich-germany-42405
# -> Algorithms, GCP, Machine Learning, Python, SQL, Spark
# ...
# ----> skipping - no keywords found
# Scraping job offer 988/1074 (91.99%): https://www.arbeitnow.com/jobs/companies/munich-electrification-gmbh/senior-embedded-software-developer-c-munich-367889
# -> Agile, Algorithms, CI/CD
# Scraping job offer 989/1074 (92.09%): https://www.arbeitnow.com/jobs/companies/kpler/senior-full-stack-engineer-germany-204917
# -> Agile, CI/CD, Data Engineering, DevOps, GitHub, Java, Scala
# Scraping job offer 990/1074 (92.18%): https://www.arbeitnow.com/jobs/companies/finn/remote-associate-backend-engineer-nodejs-379399
# -> Agile, SQL
# Scraping job offer 991/1074 (92.27%): https://www.arbeitnow.com/jobs/companies/bolt-technology/scooters-mechanic-bremen-499585
# ----> skipping - no keywords found
# Scraping job offer 992/1074 (92.36%): https://www.arbeitnow.com/jobs/companies/bolt-technology/scooters-mechanic-halle-498809
# ----> skipping - no keywords found
# Scraping job offer 993/1074 (92.46%): https://www.arbeitnow.com/jobs/companies/bolt-technology/fleet-operations-driver-solingen-34277
# ----> skipping - no keywords found
# Scraping job offer 994/1074 (92.55%): https://www.arbeitnow.com/jobs/companies/bolt-technology/fleet-operations-driver-bielefeld-312349
# ----> skipping - no keywords found
# Scraping job offer 995/1074 (92.64%): https://www.arbeitnow.com/jobs/companies/bolt-technology/scooters-mechanic-essen-74340
# ----> skipping - no keywords found
# Scraping job offer 996/1074 (92.74%): https://www.arbeitnow.com/jobs/companies/bolt-technology/fleet-operations-driver-karlsruhe-215135
# ----> skipping - no keywords found
# Scraping job offer 997/1074 (92.83%): https://www.arbeitnow.com/jobs/companies/bolt-technology/scooters-mechanic-munich-344444
# ----> skipping - no keywords found
# Scraping job offer 998/1074 (92.92%): https://www.arbeitnow.com/jobs/companies/bolt-technology/scooters-mechanic-wolfsburg-119917
# ----> skipping - no keywords found
# Scraping job offer 999/1074 (93.02%): https://www.arbeitnow.com/jobs/companies/bolt-technology/scooters-mechanic-hanover-320594
# ----> skipping - no keywords found
# Scraping job offer 1000/1074 (93.11%): https://www.arbeitnow.com/jobs/companies/bolt-technology/scooters-mechanic-hamburg-436007
# ----> skipping - no keywords found
# Scraping job offer 1001/1074 (93.20%): https://www.arbeitnow.com/jobs/companies/bolt-technology/fleet-operations-driver-munster-284703
# ----> skipping - no keywords found
# Scraping job offer 1002/1074 (93.30%): https://www.arbeitnow.com/jobs/companies/bolt-technology/fleet-operations-driver-reutlingen-421040
# ----> skipping - no keywords found
# Scraping job offer 1003/1074 (93.39%): https://www.arbeitnow.com/jobs/companies/bolt-technology/scooters-mechanic-kassel-430726
# ----> skipping - no keywords found
# Scraping job offer 1004/1074 (93.48%): https://www.arbeitnow.com/jobs/companies/bolt-technology/fleet-operations-driver-kiel-170620
# ----> skipping - no keywords found
# Scraping job offer 1005/1074 (93.58%): https://www.arbeitnow.com/jobs/companies/bolt-technology/scooters-mechanic-bielefeld-315008
# ----> skipping - no keywords found
# Scraping job offer 1006/1074 (93.67%): https://www.arbeitnow.com/jobs/companies/bolt-technology/scooters-mechanic-kiel-40180
# ----> skipping - no keywords found
# Scraping job offer 1007/1074 (93.76%): https://www.arbeitnow.com/jobs/companies/bolt-technology/fleet-operations-driver-munich-487202
# ----> skipping - no keywords found
# Scraping job offer 1008/1074 (93.85%): https://www.arbeitnow.com/jobs/companies/bolt-technology/fleet-operations-driver-halle-125690
# ----> skipping - no keywords found
# Scraping job offer 1009/1074 (93.95%): https://www.arbeitnow.com/jobs/companies/bolt-technology/fleet-operations-driver-bremen-188386
# ----> skipping - no keywords found
# Scraping job offer 1010/1074 (94.04%): https://www.arbeitnow.com/jobs/companies/bolt-technology/fleet-operations-driver-dortmund-28903
# ----> skipping - no keywords found
# Scraping job offer 1011/1074 (94.13%): https://www.arbeitnow.com/jobs/companies/bolt-technology/fleet-operations-driver-nuremberg-454279
# ----> skipping - no keywords found
# Scraping job offer 1012/1074 (94.23%): https://www.arbeitnow.com/jobs/companies/bolt-technology/fleet-operations-driver-wolfsburg-66854
# ----> skipping - no keywords found
# Scraping job offer 1013/1074 (94.32%): https://www.arbeitnow.com/jobs/companies/bolt-technology/fleet-operations-driver-frankfurt-4393
# ----> skipping - no keywords found
# Scraping job offer 1014/1074 (94.41%): https://www.arbeitnow.com/jobs/companies/bolt-technology/fleet-operations-driver-cologne-238568
# ----> skipping - no keywords found
# Scraping job offer 1015/1074 (94.51%): https://www.arbeitnow.com/jobs/companies/bolt-technology/fleet-operations-driver-hamburg-395979
# ----> skipping - no keywords found
# Scraping job offer 1016/1074 (94.60%): https://www.arbeitnow.com/jobs/companies/bolt-technology/fleet-operations-driver-stuttgart-392429
# ----> skipping - no keywords found
# Scraping job offer 1017/1074 (94.69%): https://www.arbeitnow.com/jobs/companies/bolt-technology/scooters-mechanic-berlin-358423
# ----> skipping - no keywords found
# Scraping job offer 1018/1074 (94.79%): https://www.arbeitnow.com/jobs/companies/welocalize/hungarian-localization-qa-tester-part-time-remote-in-germany-212688
# -> Machine Learning, NLP
# Scraping job offer 1019/1074 (94.88%): https://www.arbeitnow.com/jobs/companies/toloka-ai/remote-freelance-site-reliability-engineer-security-automation-penetration-testing-frankfurt-331993
# -> API, AWS, Azure, CI/CD, Cloud, DevOps, Docker, Kubernetes, Linux, ML, Python, Web Scraping
# Scraping job offer 1020/1074 (94.97%): https://www.arbeitnow.com/jobs/companies/toloka-ai/remote-freelance-site-reliability-engineer-security-automation-penetration-testing-munich-346493
# -> API, AWS, Azure, CI/CD, Cloud, DevOps, Docker, Kubernetes, Linux, ML, Python, Web Scraping
# Scraping job offer 1021/1074 (95.07%): https://www.arbeitnow.com/jobs/companies/toloka-ai/remote-freelance-site-reliability-engineer-security-automation-penetration-testing-hamburg-45319
# -> API, AWS, Azure, CI/CD, Cloud, DevOps, Docker, Kubernetes, Linux, ML, Python, Web Scraping
# Scraping job offer 1022/1074 (95.16%): https://www.arbeitnow.com/jobs/companies/toloka-ai/remote-freelance-site-reliability-engineer-security-automation-penetration-testing-berlin-377765
# -> API, AWS, Azure, CI/CD, Cloud, DevOps, Docker, Kubernetes, Linux, ML, Python, Web Scraping
# Scraping job offer 1023/1074 (95.25%): https://www.arbeitnow.com/jobs/companies/toloka-ai/remote-freelance-site-reliability-engineer-security-automation-penetration-testing-germany-68471
# -> API, AWS, Azure, CI/CD, Cloud, DevOps, Docker, Kubernetes, Linux, ML, Python, Web Scraping
# Scraping job offer 1024/1074 (95.34%): https://www.arbeitnow.com/jobs/companies/projectfitter/remote-senior-product-manager-germany-245994
# -> ML
# Scraping job offer 1025/1074 (95.44%): https://www.arbeitnow.com/jobs/companies/jobgether/software-engineer-intermediate-remote-germany-78359
# -> Java, Python, REST
# Scraping job offer 1026/1074 (95.53%): https://www.arbeitnow.com/jobs/companies/jobgether/senior-softwareentwickler-php-perspektive-c-net-remote-germany-70947
# -> Scrum
# Scraping job offer 1027/1074 (95.62%): https://www.arbeitnow.com/jobs/companies/yendou/intern-working-student-software-engineering-berlin-206071
# -> ETL, GitHub, PostgreSQL, Python, R
# Scraping job offer 1028/1074 (95.72%): https://www.arbeitnow.com/jobs/companies/orbem/senior-software-engineer-in-test-munchen-89203
# -> Microservices
# Scraping job offer 1029/1074 (95.81%): https://www.arbeitnow.com/jobs/companies/techbizglobal/senior-full-stack-developer-berlin-344735
# ----> skipping - no keywords found
# Scraping job offer 1030/1074 (95.90%): https://www.arbeitnow.com/jobs/companies/glorya-gmbh/full-stack-engineer-ai-software-start-up-berlin-435497
# ----> skipping - no keywords found
# Scraping job offer 1031/1074 (96.00%): https://www.arbeitnow.com/jobs/companies/sap-leanix/senior-ux-product-designer-bonn-90405
# -> Agile, SAP
# Scraping job offer 1032/1074 (96.09%): https://www.arbeitnow.com/jobs/companies/applike/tech-lead-backend-services-go-hamburg-447188
# -> AWS, Azure, CI/CD, Cloud, Docker, GitHub, Google Cloud, Kubernetes, MongoDB, PostgreSQL, SQL
# Scraping job offer 1033/1074 (96.18%): https://www.arbeitnow.com/jobs/companies/applike/senior-qa-engineer-hamburg-24441
# -> API, Agile, BI, Docker, Kubernetes, Machine Learning
# Scraping job offer 1034/1074 (96.28%): https://www.arbeitnow.com/jobs/companies/applike/senior-go-developer-advertising-dashboard-team-hamburg-7613
# -> API, BI, Data Lake, Docker, Machine Learning
# Scraping job offer 1035/1074 (96.37%): https://www.arbeitnow.com/jobs/companies/applike/senior-go-backend-developer-hamburg-336184
# -> API, BI, Cloud, Data Lake, Data Science, Docker, Kubernetes
# Scraping job offer 1036/1074 (96.46%): https://www.arbeitnow.com/jobs/companies/applike/senior-devops-engineer-hamburg-185098
# -> AWS, Apache, CI/CD, Cloud, DevOps, Kubernetes, Microservices, Python, Spark
# Scraping job offer 1037/1074 (96.55%): https://www.arbeitnow.com/jobs/companies/applike/senior-devops-engineer-hamburg-143640
# -> AWS, Apache, CI/CD, Cloud, DevOps, Kubernetes, Microservices, Spark
# Scraping job offer 1038/1074 (96.65%): https://www.arbeitnow.com/jobs/companies/applike/senior-data-scientist-recommendation-systems-expert-hamburg-228294
# -> AWS, Algorithms, Data Science, Deep Learning, PyTorch, Python, R, Scala, Spark, TensorFlow
# Scraping job offer 1039/1074 (96.74%): https://www.arbeitnow.com/jobs/companies/applike/devops-engineer-hamburg-39433
# -> AWS, Apache, CI/CD, Cloud, DevOps, Docker, Kubernetes, Linux, Python, Spark
# Scraping job offer 1040/1074 (96.83%): https://www.arbeitnow.com/jobs/companies/bolt-technology/fleet-operations-assistant-dusseldorf-386390
# ----> skipping - no keywords found
# Scraping job offer 1041/1074 (96.93%): https://www.arbeitnow.com/jobs/companies/crazylabs/remote-senior-game-data-analyst-berlin-229490
# -> Data Mining, SQL, Statistical Analysis, Statistics, Tableau
# Scraping job offer 1042/1074 (97.02%): https://www.arbeitnow.com/jobs/companies/proemion/senior-software-engineer-devops-gn-remote-in-europe-germany-hq-fulda-215094
# -> AWS, CI/CD, Cloud, DevOps, Docker, Linux, Python, REST
# Scraping job offer 1043/1074 (97.11%): https://www.arbeitnow.com/jobs/companies/miss-moneypenny-technologies-gmbh/digital-marketing-events-manager-berlin-138468
# -> R
# Scraping job offer 1044/1074 (97.21%): https://www.arbeitnow.com/jobs/companies/miss-moneypenny-technologies-gmbh/marketing-strategist-category-design-berlin-432681
# -> R
# Scraping job offer 1045/1074 (97.30%): https://www.arbeitnow.com/jobs/companies/q-ant-gmbh/computing-software-architect-stuttgart-118940
# -> R
# Scraping job offer 1046/1074 (97.39%): https://www.arbeitnow.com/jobs/companies/tangany-gmbh/full-stack-developer-munich-482817
# -> API, Azure, CI/CD, DevOps, GraphQL, Kubernetes, MongoDB, NoSQL, REST, SQL
# * Saved 50 job offers to CSV. Total saved: 700 (65.18%)
#
# Scraping job offer 1047/1074 (97.49%): https://www.arbeitnow.com/jobs/companies/doctorly-gmbh/senior-backend-engineer-berlin-195299
# -> API, Agile, CI/CD, DevOps, Docker, Git, PostgreSQL, REST, Scrum
# Scraping job offer 1048/1074 (97.58%): https://www.arbeitnow.com/jobs/companies/code-gaia/intermediate-frontend-engineer-all-genders-berlin-172563
# -> Django, Python
# Scraping job offer 1049/1074 (97.67%): https://www.arbeitnow.com/jobs/companies/salesplaybook-ag/b2b-pipeline-generation-consultant-berlin-265067
# ----> skipping - no keywords found
# Scraping job offer 1050/1074 (97.77%): https://www.arbeitnow.com/jobs/companies/caiz/chief-strategy-officer-cso-crypto-blockchain-frankfurt-385595
# ----> skipping - no keywords found
# Scraping job offer 1051/1074 (97.86%): https://www.arbeitnow.com/jobs/companies/caiz/chief-information-officer-cio-crypto-blockchain-frankfurt-135258
# -> Cloud
# Scraping job offer 1052/1074 (97.95%): https://www.arbeitnow.com/jobs/companies/lightcone-capital/co-founder-cxo-digital-first-tax-advisory-remote-munich-214109
# ----> skipping - no keywords found
# Scraping job offer 1053/1074 (98.04%): https://www.arbeitnow.com/jobs/companies/flummox/amazon-ppc-manager-remote-at-group-of-e-commerce-brands-berlin-495276
# ----> skipping - no keywords found
# Scraping job offer 1054/1074 (98.14%): https://www.arbeitnow.com/jobs/companies/trbe/robotics-lead-berlin-232204
# -> Algorithms, Deep Learning, Python
# Scraping job offer 1055/1074 (98.23%): https://www.arbeitnow.com/jobs/companies/medic-assist-gmbh/account-manager-corporate-clients-key-accounts-bochum-46400
# ----> skipping - no keywords found
# Scraping job offer 1056/1074 (98.32%): https://www.arbeitnow.com/jobs/companies/aroundhome/senior-data-analyst-all-genders-berlin-hybrid-or-remote-53734
# -> BI, Data Engineering, Data Science, Data Visualization, Python, R, SQL, Statistical Analysis, Statistics, Tableau
# Scraping job offer 1057/1074 (98.42%): https://www.arbeitnow.com/jobs/companies/hornetsecurity/product-owner-hanover-20661
# -> Cloud, Confluence, Jira
# Scraping job offer 1058/1074 (98.51%): https://www.arbeitnow.com/jobs/companies/billie/senior-product-manager-risk-berlin-207015
# -> ML, SQL
# Scraping job offer 1059/1074 (98.60%): https://www.arbeitnow.com/jobs/companies/billie/it-support-engineer-berlin-465464
# -> Agile, Confluence
# Scraping job offer 1060/1074 (98.70%): https://www.arbeitnow.com/jobs/companies/ping-identity/rvp-dach-munich-19984
# -> Cloud
# Scraping job offer 1061/1074 (98.79%): https://www.arbeitnow.com/jobs/companies/spire/junior-office-manager-administrative-assistant-munich-158771
# -> Algorithms, Cloud
# Scraping job offer 1062/1074 (98.88%): https://www.arbeitnow.com/jobs/companies/dlthub/remote-freelance-developer-to-build-iceberg-support-in-dlt-berlin-91530
# -> BigQuery, Data Engineering, Python, SQL
# Scraping job offer 1063/1074 (98.98%): https://www.arbeitnow.com/jobs/companies/replug/advertising-client-success-manager-remote-berlin-470957
# ----> skipping - no keywords found
# Scraping job offer 1064/1074 (99.07%): https://www.arbeitnow.com/jobs/companies/juit-gmbh/junior-performance-marketing-manager-berlin-215108
# ----> skipping - no keywords found
# Scraping job offer 1065/1074 (99.16%): https://www.arbeitnow.com/jobs/companies/xylem-water-solutions/ci-specialist-continuous-improvement-business-partner-wss-segment-europe-ludwigshafen-481412
# ----> skipping - no keywords found
# Scraping job offer 1066/1074 (99.26%): https://www.arbeitnow.com/jobs/companies/verkstedt-gmbh/mid-range-senior-cloud-infrastructure-engineer-berlin-20105
# -> Cloud, GCP, Google Cloud, Kubernetes
# Scraping job offer 1067/1074 (99.35%): https://www.arbeitnow.com/jobs/companies/billie/senior-content-marketing-manager-copywriter-english-speaking-berlin-183919
# -> Agile
# Scraping job offer 1068/1074 (99.44%): https://www.arbeitnow.com/jobs/companies/atolls/working-student-social-media-assistant-berlin-386728
# -> Cloud
# Scraping job offer 1069/1074 (99.53%): https://www.arbeitnow.com/jobs/companies/q-energy/working-student-digital-transformation-all-genders-berlin-247133
# -> Agile, BI, DevOps, Power BI
# Scraping job offer 1070/1074 (99.63%): https://www.arbeitnow.com/jobs/companies/project-a-ventures/senior-tech-recruiter-berlin-30890
# -> R
# Scraping job offer 1071/1074 (99.72%): https://www.arbeitnow.com/jobs/companies/ufynd/senior-backend-engineer-nodejs-nestjs-berlin-40149
# ----> skipping - no keywords found
# Scraping job offer 1072/1074 (99.81%): https://www.arbeitnow.com/jobs/companies/fundedclub/senior-software-engineer-ios-swift-freiburg-im-breisgau-208168
# -> Agile, Git, GraphQL, REST
# Scraping job offer 1073/1074 (99.91%): https://www.arbeitnow.com/jobs/companies/uncountable/working-student-software-engineer-munich-251570
# -> Flask, Python
# Scraping job offer 1074/1074 (100.00%): https://www.arbeitnow.com/jobs/companies/uncountable/working-student-software-engineer-munich-478552
# -> Flask, Python
# * Saved remaining 19 job offers to CSV. Total saved: 719 (66.95%)
#
# Total number of saved job offers: 719
# Time: 225.30 seconds

# %% [markdown]
# # 3. Prepare collected data for further analysis

# %%
# Load the CSV file
df = pd.read_csv("arbeitnow_jobs.csv")

# Remove duplicates based on 'Date_Posted', 'Title' and 'Company'
df = df.drop_duplicates(subset=['Date_Posted', 'Title', 'Company', 'Location', 
                                'Remote', 'Salary', 'Keywords', 'Description'])
print(f"Number of unique saved job offers: {len(df)}")

# Convert 'Date_Posted' to datetime
df['Date_Posted'] = pd.to_datetime(df['Date_Posted'], errors='coerce')

# Split 'Salary' into 'Min_Salary' and 'Max_Salary'
def split_salary(s):
    try:
        if pd.isna(s) or not isinstance(s, str) or s.strip() == "":
            return pd.Series([None, None])

        # Replace non-standard characters
        s = s.replace("–", "-").replace("\n", "").replace("€", "").strip()
        
        # Handle different salary formats
        parts = s.split("-")
        parts = [p.strip().replace(".", "").replace(",", "") for p in parts]

        if len(parts) == 1 and parts[0].isdigit():
            return pd.Series([int(parts[0]), int(parts[0])])
        elif len(parts) == 2 and all(p.isdigit() for p in parts):
            return pd.Series([int(parts[0]), int(parts[1])])
        else:
            return pd.Series([None, None])

    except Exception as e:
        print(f"Error parsing salary: {s} -> {e}")
        return pd.Series([None, None])

df[['Min_Salary [€]', 'Max_Salary [€]']] = df['Salary'].apply(split_salary)

# Prepare for column reordering
min_salary_col = 'Min_Salary [€]'
max_salary_col = 'Max_Salary [€]'
cols = df.columns.tolist()
salary_index = cols.index('Salary')

# Reorder columns
new_order = (
    cols[:salary_index + 1] +
    [min_salary_col, max_salary_col] +
    [col for col in cols if col not in [min_salary_col, max_salary_col] and col not in cols[:salary_index + 1]]
)

df = df[new_order]

# Save cleaned and updated data
df.to_csv("arbeitnow_jobs_preprocessed.csv", index=False)
print(f"Total number of saved job offers: {len(df)}")

# Show sample
df[['Date_Posted', 'Title', 'Company', 'Location', 'Remote', 'Salary', 
    'Min_Salary [€]', 'Max_Salary [€]', 'Keywords']]
# Out:
# Number of unique saved job offers: 718
# Total number of saved job offers: 718
#             Date_Posted                                              Title  \
# 0   2025-04-07 21:49:07                  Solution Consultant (all genders)
# 1   2025-04-07 19:49:03  Senior Backend & DevOps Engineer (Spring Boot ...
# 2   2025-04-07 19:09:42                                 Working Student IT
# 3   2025-04-07 17:49:05                         Head of Data (all genders)
# 4   2025-04-07 16:49:06               Working Student - Frontend Developer
# ..                  ...                                                ...
# 714 2025-02-17 13:20:18  Working Student Digital Transformation (all ge...
# 715 2025-02-17 12:49:03                    (Senior) Tech Recruiter (m/f/d)
# 716 2025-02-17 08:45:16              Senior Software Engineer - iOS, Swift
# 717 2025-02-17 07:04:07       Working Student -- Software Engineer: Munich
# 718 2025-02-17 07:04:07       Working Student -- Software Engineer: Munich
#
#                     Company              Location Remote Salary  \
# 0                 TradeLink                Munich    Yes    NaN
# 1    pathway solutions gmbh               Hamburg    Yes    NaN
# 2               BigRep GmbH                Berlin     No    NaN
# 3             JustPlay GmbH                Berlin    Yes    NaN
# 4                perto GmbH                Berlin     No    NaN
# ..                      ...                   ...    ...    ...
# 714                Q Energy                Berlin     No    NaN
# 715      Project A Ventures                Berlin     No    NaN
# 716             Funded.club  Freiburg im Breisgau     No    NaN
# 717             Uncountable                Munich     No    NaN
# 718             Uncountable                Munich     No    NaN
#
#      Min_Salary [€]  Max_Salary [€]  \
# 0               NaN             NaN
# 1               NaN             NaN
# 2               NaN             NaN
# 3               NaN             NaN
# 4               NaN             NaN
# ..              ...             ...
# 714             NaN             NaN
# 715             NaN             NaN
# 716             NaN             NaN
# 717             NaN             NaN
# 718             NaN             NaN
#
#                                               Keywords
# 0                                               API, R
# 1    API, CI/CD, Cloud, DevOps, GCP, Google Cloud, ...
# 2                                    AWS, Azure, Cloud
# 3    Cloud, Docker, GCP, Git, Google Cloud, Python,...
# 4                                           API, Agile
# ..                                                 ...
# 714                        Agile, BI, DevOps, Power BI
# 715                                                  R
# 716                          Agile, Git, GraphQL, REST
# 717                                      Flask, Python
# 718                                      Flask, Python
#
# [718 rows x 9 columns]
